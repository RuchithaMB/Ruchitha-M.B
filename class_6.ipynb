# %% [markdown]
# <a href="https://colab.research.google.com/github/RuchithaMB/Ruchitha-M.B/blob/main/class_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from itertools import permutations 
x=['rama','krishna','hari','you','and','me']
result = list(permutations(x))
for i in result :
  print(i)
p= len(result)
print("number of permutations: ",p)
# Out:
# ('rama', 'krishna', 'hari', 'you', 'and', 'me')
# ('rama', 'krishna', 'hari', 'you', 'me', 'and')
# ('rama', 'krishna', 'hari', 'and', 'you', 'me')
# ('rama', 'krishna', 'hari', 'and', 'me', 'you')
# ('rama', 'krishna', 'hari', 'me', 'you', 'and')
# ('rama', 'krishna', 'hari', 'me', 'and', 'you')
# ('rama', 'krishna', 'you', 'hari', 'and', 'me')
# ('rama', 'krishna', 'you', 'hari', 'me', 'and')
# ('rama', 'krishna', 'you', 'and', 'hari', 'me')
# ('rama', 'krishna', 'you', 'and', 'me', 'hari')
# ('rama', 'krishna', 'you', 'me', 'hari', 'and')
# ('rama', 'krishna', 'you', 'me', 'and', 'hari')
# ('rama', 'krishna', 'and', 'hari', 'you', 'me')
# ('rama', 'krishna', 'and', 'hari', 'me', 'you')
# ('rama', 'krishna', 'and', 'you', 'hari', 'me')
# ('rama', 'krishna', 'and', 'you', 'me', 'hari')
# ('rama', 'krishna', 'and', 'me', 'hari', 'you')
# ('rama', 'krishna', 'and', 'me', 'you', 'hari')
# ('rama', 'krishna', 'me', 'hari', 'you', 'and')
# ('rama', 'krishna', 'me', 'hari', 'and', 'you')
# ...

# %%
from itertools import permutations 
x=[21.09,'r','k','3']
result = list(permutations(x))
for i in result :
  print(i)
p= len(result)
print("number of permutations: ",p)
# Out:
# (21.09, 'r', 'k', '3')
# (21.09, 'r', '3', 'k')
# (21.09, 'k', 'r', '3')
# (21.09, 'k', '3', 'r')
# (21.09, '3', 'r', 'k')
# (21.09, '3', 'k', 'r')
# ('r', 21.09, 'k', '3')
# ('r', 21.09, '3', 'k')
# ('r', 'k', 21.09, '3')
# ('r', 'k', '3', 21.09)
# ('r', '3', 21.09, 'k')
# ('r', '3', 'k', 21.09)
# ('k', 21.09, 'r', '3')
# ('k', 21.09, '3', 'r')
# ('k', 'r', 21.09, '3')
# ('k', 'r', '3', 21.09)
# ('k', '3', 21.09, 'r')
# ('k', '3', 'r', 21.09)
# ('3', 21.09, 'r', 'k')
# ('3', 21.09, 'k', 'r')
# ('3', 'r', 21.09, 'k')
# ('3', 'r', 'k', 21.09)
# ('3', 'k', 21.09, 'r')
# ('3', 'k', 'r', 21.09)
# number of permutations:  24
